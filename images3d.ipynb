# %%
import numpy as np, matplotlib.pyplot as plt
from pathlib import Path
import os, math

# %%
A = np.load('/raid/mpsych/OMAMA/DATA/data/3d/images/2.25.87205271496965794377093206794313557396.npz')['data']

# %%
A.shape
# Out:
# (72, 2457, 1890)

# %%
print(len(A))
# Out:
# 72

# %%
plt.imshow(A[36], cmap = 'gray')

# %%
images_path = '/raid/mpsych/OMAMA/DATA/data/3d/images/2.25.303752069057352316286604420537828606550.npz'
A = np.load('/raid/mpsych/OMAMA/DATA/data/3d/images/2.25.303752069057352316286604420537828606550.npz')['data']
cols = 5
rows = math.ceil(len(A)/cols)
fig, axes = plt.subplots(rows, cols, figsize=(3 * cols, 3 * rows))
axes = axes.ravel()

for ax, image in zip(axes, A) :
    ax.imshow(image, cmap = "gray")

plt.tight_layout()
plt.show()
